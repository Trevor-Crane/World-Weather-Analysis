# %%
# Import the dependencies.
import pandas as pd
import matplotlib as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []

#Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #If the city in unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
#Print the city count to confirm sufficient count
len(cities)
# Out:
# 752

# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call
url = "https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data=[]

#Print the beginning of the logging
print("Beginning Data Retrieval      ")
print("------------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for loggin purposes
    if(i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    #Create endpoint URL with each city.
    city_url=url + "&q=" + cities[i]
    
    #Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 1 of Set 1 | tilichiki
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | grindavik
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | amapa
# Processing Record 9 of Set 1 | khorixas
# Processing Record 10 of Set 1 | ostrovnoy
# Processing Record 11 of Set 1 | pangnirtung
# Processing Record 12 of Set 1 | kruisfontein
# Processing Record 13 of Set 1 | alofi
# Processing Record 14 of Set 1 | the valley
# Processing Record 15 of Set 1 | manzil tamim
# City not found. Skipping...
# Processing Record 16 of Set 1 | faya
# Processing Record 17 of Set 1 | kuusamo
# Processing Record 18 of Set 1 | yoichi
# Processing Record 19 of Set 1 | takoradi
# Processing Record 20 of Set 1 | pleasanton
# Processing Record 21 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 1 | vardo
# Processing Record 23 of Set 1 | riyadh
# Processing Record 24 of Set 1 | edd
# Processing Record 25 of Set 1 | butaritari
# Processing Record 26 of Set 1 | chokurdakh
# Processing Record 27 of Set 1 | arraial do cabo
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 1 | hami
# Processing Record 31 of Set 1 | vangaindrano
# Processing Record 32 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 1 | aguimes
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | saint anthony
# Processing Record 36 of Set 1 | mgandu
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | lodja
# Processing Record 39 of Set 1 | hilo
# Processing Record 40 of Set 1 | north platte
# Processing Record 41 of Set 1 | airai
# Processing Record 42 of Set 1 | pisco
# Processing Record 43 of Set 1 | araouane
# Processing Record 44 of Set 1 | esil
# Processing Record 45 of Set 1 | paita
# Processing Record 46 of Set 1 | kanniyakumari
# Processing Record 47 of Set 1 | hithadhoo
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | coihaique
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | broome
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | nikolskoye
# Processing Record 4 of Set 2 | palaia fokaia
# Processing Record 5 of Set 2 | manzhouli
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | skagastrond
# City not found. Skipping...
# Processing Record 8 of Set 2 | opuwo
# Processing Record 9 of Set 2 | upernavik
# Processing Record 10 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 2 | tynset
# Processing Record 12 of Set 2 | troitsko-pechorsk
# Processing Record 13 of Set 2 | dunedin
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | sao filipe
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | kloulklubed
# Processing Record 18 of Set 2 | muros
# Processing Record 19 of Set 2 | xining
# Processing Record 20 of Set 2 | nantucket
# Processing Record 21 of Set 2 | slave lake
# Processing Record 22 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 2 | oktyabrskoye
# Processing Record 24 of Set 2 | albany
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | tsaratanana
# Processing Record 27 of Set 2 | busselton
# Processing Record 28 of Set 2 | abu kamal
# Processing Record 29 of Set 2 | east london
# Processing Record 30 of Set 2 | san jeronimo
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | labuhan
# Processing Record 33 of Set 2 | saint-augustin
# Processing Record 34 of Set 2 | la asuncion
# Processing Record 35 of Set 2 | awbari
# Processing Record 36 of Set 2 | manuk mangkaw
# Processing Record 37 of Set 2 | pangai
# Processing Record 38 of Set 2 | kargasok
# Processing Record 39 of Set 2 | kodiak
# Processing Record 40 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | victoria
# Processing Record 44 of Set 2 | chicama
# Processing Record 45 of Set 2 | sant feliu de guixols
# Processing Record 46 of Set 2 | verkhnyaya toyma
# Processing Record 47 of Set 2 | azle
# Processing Record 48 of Set 2 | rock sound
# Processing Record 49 of Set 2 | cherskiy
# Processing Record 50 of Set 2 | atuona
# Processing Record 1 of Set 3 | iskateley
# Processing Record 2 of Set 3 | avarua
# Processing Record 3 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 3 | seoul
# Processing Record 5 of Set 3 | constitucion
# Processing Record 6 of Set 3 | yokadouma
# Processing Record 7 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 3 | ribeirao branco
# Processing Record 9 of Set 3 | bela
# Processing Record 10 of Set 3 | qaanaaq
# Processing Record 11 of Set 3 | srednekolymsk
# Processing Record 12 of Set 3 | ojinaga
# Processing Record 13 of Set 3 | arys
# Processing Record 14 of Set 3 | longyearbyen
# Processing Record 15 of Set 3 | beidao
# Processing Record 16 of Set 3 | khatanga
# Processing Record 17 of Set 3 | lavrentiya
# Processing Record 18 of Set 3 | umm lajj
# Processing Record 19 of Set 3 | port blair
# Processing Record 20 of Set 3 | katsuura
# Processing Record 21 of Set 3 | doctor arroyo
# Processing Record 22 of Set 3 | ponta do sol
# Processing Record 23 of Set 3 | topolobampo
# Processing Record 24 of Set 3 | bambous virieux
# Processing Record 25 of Set 3 | sao joao da barra
# Processing Record 26 of Set 3 | berea
# Processing Record 27 of Set 3 | cayenne
# Processing Record 28 of Set 3 | san anselmo
# Processing Record 29 of Set 3 | pacific grove
# Processing Record 30 of Set 3 | chernyshevskiy
# Processing Record 31 of Set 3 | shimoda
# Processing Record 32 of Set 3 | kavieng
# Processing Record 33 of Set 3 | leningradskiy
# Processing Record 34 of Set 3 | smithers
# Processing Record 35 of Set 3 | kshenskiy
# Processing Record 36 of Set 3 | bethel
# Processing Record 37 of Set 3 | naze
# Processing Record 38 of Set 3 | chuy
# Processing Record 39 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 3 | clarksburg
# Processing Record 41 of Set 3 | jiayuguan
# Processing Record 42 of Set 3 | hamilton
# Processing Record 43 of Set 3 | saskylakh
# Processing Record 44 of Set 3 | tuatapere
# Processing Record 45 of Set 3 | umm durman
# City not found. Skipping...
# Processing Record 46 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 47 of Set 3 | lorengau
# Processing Record 48 of Set 3 | luderitz
# Processing Record 49 of Set 3 | lebu
# Processing Record 50 of Set 3 | flin flon
# Processing Record 1 of Set 4 | pimentel
# Processing Record 2 of Set 4 | tacoronte
# Processing Record 3 of Set 4 | banjaran
# Processing Record 4 of Set 4 | faanui
# Processing Record 5 of Set 4 | hobyo
# Processing Record 6 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 7 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 4 | wewak
# Processing Record 9 of Set 4 | hofn
# Processing Record 10 of Set 4 | gayeri
# Processing Record 11 of Set 4 | saldanha
# Processing Record 12 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 4 | quatre cocos
# Processing Record 14 of Set 4 | batagay
# Processing Record 15 of Set 4 | ahipara
# Processing Record 16 of Set 4 | vaini
# Processing Record 17 of Set 4 | cidreira
# Processing Record 18 of Set 4 | geresk
# City not found. Skipping...
# Processing Record 19 of Set 4 | nanortalik
# Processing Record 20 of Set 4 | aksu
# Processing Record 21 of Set 4 | nome
# Processing Record 22 of Set 4 | parabel
# Processing Record 23 of Set 4 | mehkar
# Processing Record 24 of Set 4 | kahului
# Processing Record 25 of Set 4 | caxito
# Processing Record 26 of Set 4 | kayiry
# Processing Record 27 of Set 4 | savonlinna
# Processing Record 28 of Set 4 | pevek
# Processing Record 29 of Set 4 | singapore
# Processing Record 30 of Set 4 | morant bay
# Processing Record 31 of Set 4 | iqaluit
# Processing Record 32 of Set 4 | manoel urbano
# Processing Record 33 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 4 | calamar
# Processing Record 35 of Set 4 | comodoro rivadavia
# Processing Record 36 of Set 4 | hearst
# Processing Record 37 of Set 4 | mar del plata
# Processing Record 38 of Set 4 | mahebourg
# Processing Record 39 of Set 4 | maceio
# Processing Record 40 of Set 4 | kanigoro
# Processing Record 41 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 4 | matagami
# Processing Record 43 of Set 4 | do gonbadan
# Processing Record 44 of Set 4 | gat
# Processing Record 45 of Set 4 | provideniya
# Processing Record 46 of Set 4 | puerto ayora
# Processing Record 47 of Set 4 | port angeles
# Processing Record 48 of Set 4 | padang
# Processing Record 49 of Set 4 | komsomolskiy
# Processing Record 50 of Set 4 | along
# Processing Record 1 of Set 5 | aksarka
# Processing Record 2 of Set 5 | codrington
# Processing Record 3 of Set 5 | ola
# Processing Record 4 of Set 5 | formoso do araguaia
# City not found. Skipping...
# Processing Record 5 of Set 5 | thompson
# Processing Record 6 of Set 5 | robertsport
# Processing Record 7 of Set 5 | egvekinot
# Processing Record 8 of Set 5 | road town
# Processing Record 9 of Set 5 | werda
# Processing Record 10 of Set 5 | cabo san lucas
# Processing Record 11 of Set 5 | okha
# Processing Record 12 of Set 5 | esperance
# Processing Record 13 of Set 5 | saint-philippe
# Processing Record 14 of Set 5 | turan
# Processing Record 15 of Set 5 | havelock
# Processing Record 16 of Set 5 | kiama
# Processing Record 17 of Set 5 | payo
# Processing Record 18 of Set 5 | harper
# Processing Record 19 of Set 5 | bardiyah
# Processing Record 20 of Set 5 | tezu
# Processing Record 21 of Set 5 | karur
# Processing Record 22 of Set 5 | sitka
# Processing Record 23 of Set 5 | guerrero negro
# Processing Record 24 of Set 5 | auburn
# Processing Record 25 of Set 5 | georgetown
# Processing Record 26 of Set 5 | margate
# Processing Record 27 of Set 5 | imeni poliny osipenko
# Processing Record 28 of Set 5 | mayari
# City not found. Skipping...
# Processing Record 29 of Set 5 | salinopolis
# Processing Record 30 of Set 5 | godalming
# Processing Record 31 of Set 5 | beaverlodge
# Processing Record 32 of Set 5 | namibe
# Processing Record 33 of Set 5 | mankono
# Processing Record 34 of Set 5 | andevoranto
# City not found. Skipping...
# Processing Record 35 of Set 5 | bubaque
# Processing Record 36 of Set 5 | klyuchi
# Processing Record 37 of Set 5 | mildura
# Processing Record 38 of Set 5 | makakilo city
# Processing Record 39 of Set 5 | bandar
# Processing Record 40 of Set 5 | dingle
# Processing Record 41 of Set 5 | ternate
# Processing Record 42 of Set 5 | bayir
# Processing Record 43 of Set 5 | belaya kholunitsa
# Processing Record 44 of Set 5 | samagaltay
# Processing Record 45 of Set 5 | marystown
# Processing Record 46 of Set 5 | northam
# Processing Record 47 of Set 5 | latung
# Processing Record 48 of Set 5 | tiksi
# Processing Record 49 of Set 5 | haines junction
# Processing Record 50 of Set 5 | ahuimanu
# Processing Record 1 of Set 6 | noumea
# Processing Record 2 of Set 6 | methven
# Processing Record 3 of Set 6 | udachnyy
# Processing Record 4 of Set 6 | shevchenkove
# Processing Record 5 of Set 6 | warsaw
# Processing Record 6 of Set 6 | urambo
# Processing Record 7 of Set 6 | dikson
# Processing Record 8 of Set 6 | asino
# Processing Record 9 of Set 6 | shingu
# Processing Record 10 of Set 6 | sinnamary
# Processing Record 11 of Set 6 | wajir
# Processing Record 12 of Set 6 | marrakesh
# Processing Record 13 of Set 6 | alice springs
# Processing Record 14 of Set 6 | yabassi
# Processing Record 15 of Set 6 | mount gambier
# Processing Record 16 of Set 6 | san quintin
# Processing Record 17 of Set 6 | hervey bay
# Processing Record 18 of Set 6 | ilulissat
# Processing Record 19 of Set 6 | langham
# Processing Record 20 of Set 6 | wahpeton
# Processing Record 21 of Set 6 | alta floresta
# Processing Record 22 of Set 6 | srandakan
# Processing Record 23 of Set 6 | pontes e lacerda
# Processing Record 24 of Set 6 | fairbanks
# Processing Record 25 of Set 6 | kamojima
# Processing Record 26 of Set 6 | gao
# Processing Record 27 of Set 6 | jalu
# Processing Record 28 of Set 6 | half moon bay
# Processing Record 29 of Set 6 | lasa
# Processing Record 30 of Set 6 | hopkinton
# Processing Record 31 of Set 6 | morro bay
# Processing Record 32 of Set 6 | yeppoon
# Processing Record 33 of Set 6 | whitehorse
# Processing Record 34 of Set 6 | vagur
# Processing Record 35 of Set 6 | emerald
# Processing Record 36 of Set 6 | sambava
# Processing Record 37 of Set 6 | carnarvon
# Processing Record 38 of Set 6 | kupang
# Processing Record 39 of Set 6 | zavetnoye
# Processing Record 40 of Set 6 | kavaratti
# Processing Record 41 of Set 6 | deputatskiy
# Processing Record 42 of Set 6 | praia da vitoria
# Processing Record 43 of Set 6 | fort nelson
# Processing Record 44 of Set 6 | riwaka
# Processing Record 45 of Set 6 | malakal
# Processing Record 46 of Set 6 | crab hill
# City not found. Skipping...
# Processing Record 47 of Set 6 | yar-sale
# Processing Record 48 of Set 6 | avera
# Processing Record 49 of Set 6 | bengkulu
# Processing Record 50 of Set 6 | ribeira grande
# Processing Record 1 of Set 7 | conde
# Processing Record 2 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 7 | lebedinyy
# Processing Record 4 of Set 7 | sayyan
# Processing Record 5 of Set 7 | maragogi
# Processing Record 6 of Set 7 | xapuri
# Processing Record 7 of Set 7 | tura
# Processing Record 8 of Set 7 | visby
# Processing Record 9 of Set 7 | vestmannaeyjar
# Processing Record 10 of Set 7 | mandalgovi
# Processing Record 11 of Set 7 | novo aripuana
# Processing Record 12 of Set 7 | rocha
# Processing Record 13 of Set 7 | helena
# Processing Record 14 of Set 7 | hasaki
# Processing Record 15 of Set 7 | ust-maya
# Processing Record 16 of Set 7 | mandurah
# Processing Record 17 of Set 7 | port elizabeth
# Processing Record 18 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 7 | fortuna
# Processing Record 20 of Set 7 | ladario
# Processing Record 21 of Set 7 | yulara
# Processing Record 22 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 23 of Set 7 | hay river
# Processing Record 24 of Set 7 | killarney
# Processing Record 25 of Set 7 | kieta
# Processing Record 26 of Set 7 | maun
# Processing Record 27 of Set 7 | viedma
# Processing Record 28 of Set 7 | altay
# Processing Record 29 of Set 7 | mudgee
# Processing Record 30 of Set 7 | tasiilaq
# Processing Record 31 of Set 7 | vila franca do campo
# Processing Record 32 of Set 7 | ambilobe
# Processing Record 33 of Set 7 | wahiawa
# Processing Record 34 of Set 7 | senanga
# Processing Record 35 of Set 7 | plettenberg bay
# Processing Record 36 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 37 of Set 7 | tongliao
# Processing Record 38 of Set 7 | cotonou
# Processing Record 39 of Set 7 | bayanday
# Processing Record 40 of Set 7 | san patricio
# Processing Record 41 of Set 7 | hurricane
# Processing Record 42 of Set 7 | torbay
# Processing Record 43 of Set 7 | bathsheba
# Processing Record 44 of Set 7 | paamiut
# Processing Record 45 of Set 7 | diffa
# Processing Record 46 of Set 7 | souillac
# Processing Record 47 of Set 7 | knysna
# Processing Record 48 of Set 7 | port macquarie
# Processing Record 49 of Set 7 | alihe
# Processing Record 50 of Set 7 | payakumbuh
# Processing Record 1 of Set 8 | chitral
# Processing Record 2 of Set 8 | zilupe
# Processing Record 3 of Set 8 | kaitangata
# Processing Record 4 of Set 8 | adrar
# Processing Record 5 of Set 8 | mbeya
# Processing Record 6 of Set 8 | buala
# Processing Record 7 of Set 8 | san cristobal
# Processing Record 8 of Set 8 | taksimo
# Processing Record 9 of Set 8 | kisangani
# Processing Record 10 of Set 8 | florence
# Processing Record 11 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 8 | sri aman
# Processing Record 13 of Set 8 | tucupita
# Processing Record 14 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 8 | port-cartier
# Processing Record 16 of Set 8 | necochea
# Processing Record 17 of Set 8 | mareeba
# Processing Record 18 of Set 8 | general roca
# Processing Record 19 of Set 8 | atambua
# Processing Record 20 of Set 8 | port-gentil
# Processing Record 21 of Set 8 | gravdal
# Processing Record 22 of Set 8 | borlange
# City not found. Skipping...
# Processing Record 23 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 24 of Set 8 | pozo colorado
# Processing Record 25 of Set 8 | channel-port aux basques
# Processing Record 26 of Set 8 | brae
# Processing Record 27 of Set 8 | salalah
# Processing Record 28 of Set 8 | khandbari
# Processing Record 29 of Set 8 | muli
# Processing Record 30 of Set 8 | severo-kurilsk
# Processing Record 31 of Set 8 | karatau
# Processing Record 32 of Set 8 | south lake tahoe
# Processing Record 33 of Set 8 | tuy hoa
# Processing Record 34 of Set 8 | voh
# Processing Record 35 of Set 8 | aklavik
# Processing Record 36 of Set 8 | tawang
# Processing Record 37 of Set 8 | arkhangelsk
# Processing Record 38 of Set 8 | henties bay
# Processing Record 39 of Set 8 | izhma
# Processing Record 40 of Set 8 | sinyavskoye
# Processing Record 41 of Set 8 | kununurra
# Processing Record 42 of Set 8 | wum
# Processing Record 43 of Set 8 | tupi paulista
# Processing Record 44 of Set 8 | wake forest
# Processing Record 45 of Set 8 | belmonte
# Processing Record 46 of Set 8 | west des moines
# Processing Record 47 of Set 8 | akhmim
# Processing Record 48 of Set 8 | astipalaia
# City not found. Skipping...
# Processing Record 49 of Set 8 | sobolevo
# Processing Record 50 of Set 8 | liverpool
# Processing Record 1 of Set 9 | tucuma
# Processing Record 2 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 9 | ikornnes
# Processing Record 4 of Set 9 | bonthe
# Processing Record 5 of Set 9 | jizan
# Processing Record 6 of Set 9 | bonavista
# Processing Record 7 of Set 9 | sarahan
# Processing Record 8 of Set 9 | koslan
# Processing Record 9 of Set 9 | vyatskiye polyany
# Processing Record 10 of Set 9 | jinxiang
# Processing Record 11 of Set 9 | kemijarvi
# Processing Record 12 of Set 9 | la macarena
# Processing Record 13 of Set 9 | san andres
# Processing Record 14 of Set 9 | oranjemund
# Processing Record 15 of Set 9 | jaca
# Processing Record 16 of Set 9 | cam pha
# City not found. Skipping...
# Processing Record 17 of Set 9 | vanimo
# Processing Record 18 of Set 9 | winnemucca
# Processing Record 19 of Set 9 | touros
# Processing Record 20 of Set 9 | shchelyayur
# City not found. Skipping...
# Processing Record 21 of Set 9 | sao pedro do piaui
# Processing Record 22 of Set 9 | thunder bay
# Processing Record 23 of Set 9 | el wasta
# City not found. Skipping...
# Processing Record 24 of Set 9 | zhigansk
# Processing Record 25 of Set 9 | issoire
# Processing Record 26 of Set 9 | ardahan
# Processing Record 27 of Set 9 | ornskoldsvik
# Processing Record 28 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 9 | karratha
# Processing Record 30 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 31 of Set 9 | port lincoln
# Processing Record 32 of Set 9 | narsaq
# Processing Record 33 of Set 9 | cabo rojo
# Processing Record 34 of Set 9 | prince rupert
# Processing Record 35 of Set 9 | etchoropo
# Processing Record 36 of Set 9 | kondinskoye
# Processing Record 37 of Set 9 | jose bonifacio
# Processing Record 38 of Set 9 | iguape
# Processing Record 39 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 40 of Set 9 | ancud
# Processing Record 41 of Set 9 | namatanai
# Processing Record 42 of Set 9 | seydi
# Processing Record 43 of Set 9 | muroto
# Processing Record 44 of Set 9 | taoudenni
# Processing Record 45 of Set 9 | sesheke
# Processing Record 46 of Set 9 | farafangana
# Processing Record 47 of Set 9 | derzhavinsk
# Processing Record 48 of Set 9 | juneau
# Processing Record 49 of Set 9 | sainte-rose
# Processing Record 50 of Set 9 | sawakin
# Processing Record 1 of Set 10 | arlit
# Processing Record 2 of Set 10 | stornoway
# Processing Record 3 of Set 10 | pasco
# Processing Record 4 of Set 10 | polyarnyy
# Processing Record 5 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 10 | isangel
# Processing Record 7 of Set 10 | alyangula
# Processing Record 8 of Set 10 | lao cai
# Processing Record 9 of Set 10 | clyde river
# Processing Record 10 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 11 of Set 10 | college
# Processing Record 12 of Set 10 | hambantota
# Processing Record 13 of Set 10 | krasnoselkup
# Processing Record 14 of Set 10 | jumla
# Processing Record 15 of Set 10 | poum
# Processing Record 16 of Set 10 | ulladulla
# Processing Record 17 of Set 10 | kasongo
# Processing Record 18 of Set 10 | la ronge
# Processing Record 19 of Set 10 | austin
# Processing Record 20 of Set 10 | antofagasta
# Processing Record 21 of Set 10 | norman wells
# Processing Record 22 of Set 10 | krasnoye-na-volge
# Processing Record 23 of Set 10 | menongue
# Processing Record 24 of Set 10 | chapeco
# Processing Record 25 of Set 10 | bratsk
# Processing Record 26 of Set 10 | palmer
# Processing Record 27 of Set 10 | manali
# Processing Record 28 of Set 10 | lincoln
# Processing Record 29 of Set 10 | shahdadpur
# Processing Record 30 of Set 10 | lufilufi
# Processing Record 31 of Set 10 | sjenica
# Processing Record 32 of Set 10 | atar
# Processing Record 33 of Set 10 | bolshevik
# Processing Record 34 of Set 10 | yabrud
# Processing Record 35 of Set 10 | russell
# Processing Record 36 of Set 10 | asau
# Processing Record 37 of Set 10 | zadar
# Processing Record 38 of Set 10 | king city
# Processing Record 39 of Set 10 | begoro
# Processing Record 40 of Set 10 | huarmey
# Processing Record 41 of Set 10 | los llanos de aridane
# Processing Record 42 of Set 10 | olinda
# Processing Record 43 of Set 10 | fare
# Processing Record 44 of Set 10 | mangan
# Processing Record 45 of Set 10 | pincehely
# Processing Record 46 of Set 10 | boyolangu
# Processing Record 47 of Set 10 | chipata
# Processing Record 48 of Set 10 | san juan
# Processing Record 49 of Set 10 | sisimiut
# Processing Record 50 of Set 10 | mazatlan
# Processing Record 1 of Set 11 | boa vista
# Processing Record 2 of Set 11 | dryden
# Processing Record 3 of Set 11 | alamosa
# Processing Record 4 of Set 11 | leh
# Processing Record 5 of Set 11 | richards bay
# Processing Record 6 of Set 11 | longyan
# Processing Record 7 of Set 11 | kitgum
# Processing Record 8 of Set 11 | hit
# Processing Record 9 of Set 11 | roma
# Processing Record 10 of Set 11 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 11 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 12 of Set 11 | drovyanaya
# Processing Record 13 of Set 11 | cam ranh
# Processing Record 14 of Set 11 | upington
# Processing Record 15 of Set 11 | coxim
# Processing Record 16 of Set 11 | grand gaube
# Processing Record 17 of Set 11 | doha
# Processing Record 18 of Set 11 | olafsvik
# Processing Record 19 of Set 11 | saint george
# Processing Record 20 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 11 | mangochi
# Processing Record 22 of Set 11 | barcelos
# Processing Record 23 of Set 11 | port hardy
# Processing Record 24 of Set 11 | ocala
# Processing Record 25 of Set 11 | mecca
# Processing Record 26 of Set 11 | brownsville
# Processing Record 27 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 28 of Set 11 | isabela
# Processing Record 29 of Set 11 | stephenville
# Processing Record 30 of Set 11 | sao joaquim
# Processing Record 31 of Set 11 | evensk
# Processing Record 32 of Set 11 | samarai
# Processing Record 33 of Set 11 | anton lizardo
# Processing Record 34 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 35 of Set 11 | launceston
# Processing Record 36 of Set 11 | demidov
# Processing Record 37 of Set 11 | praia
# Processing Record 38 of Set 11 | guanica
# Processing Record 39 of Set 11 | villazon
# Processing Record 40 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 41 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 42 of Set 11 | ust-kuyga
# Processing Record 43 of Set 11 | bure
# Processing Record 44 of Set 11 | puerto del rosario
# Processing Record 45 of Set 11 | cantaura
# Processing Record 46 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 11 | talnakh
# Processing Record 48 of Set 11 | bunia
# Processing Record 49 of Set 11 | thinadhoo
# Processing Record 50 of Set 11 | nipawin
# Processing Record 1 of Set 12 | broken hill
# Processing Record 2 of Set 12 | kibondo
# Processing Record 3 of Set 12 | furculesti
# City not found. Skipping...
# Processing Record 4 of Set 12 | caninde de sao francisco
# Processing Record 5 of Set 12 | fuyu
# Processing Record 6 of Set 12 | pocatello
# Processing Record 7 of Set 12 | cardenas
# Processing Record 8 of Set 12 | trzebiatow
# Processing Record 9 of Set 12 | setermoen
# Processing Record 10 of Set 12 | celestun
# Processing Record 11 of Set 12 | diego de almagro
# Processing Record 12 of Set 12 | kilindoni
# Processing Record 13 of Set 12 | mujiayingzi
# Processing Record 14 of Set 12 | vao
# Processing Record 15 of Set 12 | carutapera
# Processing Record 16 of Set 12 | alvaraes
# Processing Record 17 of Set 12 | iquique
# Processing Record 18 of Set 12 | gigmoto
# Processing Record 19 of Set 12 | san carlos de bariloche
# Processing Record 20 of Set 12 | saint-pierre
# Processing Record 21 of Set 12 | zhezkazgan
# Processing Record 22 of Set 12 | coahuayana
# Processing Record 23 of Set 12 | yeletskiy
# City not found. Skipping...
# Processing Record 24 of Set 12 | meulaboh
# Processing Record 25 of Set 12 | kaabong
# Processing Record 26 of Set 12 | ketchikan
# Processing Record 27 of Set 12 | gogrial
# Processing Record 28 of Set 12 | slavsk
# Processing Record 29 of Set 12 | roebourne
# Processing Record 30 of Set 12 | ulaangom
# Processing Record 31 of Set 12 | itaguai
# Processing Record 32 of Set 12 | klaipeda
# Processing Record 33 of Set 12 | chapais
# Processing Record 34 of Set 12 | ormara
# Processing Record 35 of Set 12 | prainha
# Processing Record 36 of Set 12 | shubarkuduk
# Processing Record 37 of Set 12 | nouadhibou
# Processing Record 38 of Set 12 | vostok
# Processing Record 39 of Set 12 | tartus
# Processing Record 40 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 41 of Set 12 | tautira
# Processing Record 42 of Set 12 | skelleftea
# Processing Record 43 of Set 12 | revelstoke
# Processing Record 44 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 12 | lompoc
# Processing Record 46 of Set 12 | sochi
# Processing Record 47 of Set 12 | vlasotince
# Processing Record 48 of Set 12 | teguldet
# Processing Record 49 of Set 12 | geraldton
# Processing Record 50 of Set 12 | murray bridge
# Processing Record 1 of Set 13 | krasnovishersk
# Processing Record 2 of Set 13 | cockburn town
# Processing Record 3 of Set 13 | gawler
# Processing Record 4 of Set 13 | akureyri
# Processing Record 5 of Set 13 | ishigaki
# Processing Record 6 of Set 13 | dauriya
# Processing Record 7 of Set 13 | lae
# Processing Record 8 of Set 13 | aripuana
# Processing Record 9 of Set 13 | west plains
# Processing Record 10 of Set 13 | marawi
# Processing Record 11 of Set 13 | iwaki
# Processing Record 12 of Set 13 | solnechnyy
# Processing Record 13 of Set 13 | idlib
# Processing Record 14 of Set 13 | zyryanka
# Processing Record 15 of Set 13 | beloha
# Processing Record 16 of Set 13 | rassvet
# Processing Record 17 of Set 13 | muisne
# Processing Record 18 of Set 13 | camapua
# Processing Record 19 of Set 13 | hornepayne
# Processing Record 20 of Set 13 | mahajanga
# Processing Record 21 of Set 13 | jardim
# Processing Record 22 of Set 13 | itumba
# Processing Record 23 of Set 13 | bababe
# City not found. Skipping...
# Processing Record 24 of Set 13 | berlevag
# Processing Record 25 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 13 | vanavara
# Processing Record 27 of Set 13 | nagymaros
# Processing Record 28 of Set 13 | nabire
# Processing Record 29 of Set 13 | gornyy
# Processing Record 30 of Set 13 | tabuny
# Processing Record 31 of Set 13 | dandong
# Processing Record 32 of Set 13 | heswall
# Processing Record 33 of Set 13 | takaungu
# Processing Record 34 of Set 13 | mayumba
# Processing Record 35 of Set 13 | kulhudhuffushi
# Processing Record 36 of Set 13 | filingue
# Processing Record 37 of Set 13 | hutchinson
# Processing Record 38 of Set 13 | aldan
# Processing Record 39 of Set 13 | terrace
# Processing Record 40 of Set 13 | lisakovsk
# Processing Record 41 of Set 13 | nadym
# Processing Record 42 of Set 13 | lashio
# Processing Record 43 of Set 13 | loikaw
# Processing Record 44 of Set 13 | laredo
# Processing Record 45 of Set 13 | ipixuna
# Processing Record 46 of Set 13 | yurimaguas
# Processing Record 47 of Set 13 | wanning
# Processing Record 48 of Set 13 | ugoofaaru
# Processing Record 49 of Set 13 | port hueneme
# Processing Record 50 of Set 13 | te anau
# Processing Record 1 of Set 14 | kirakira
# Processing Record 2 of Set 14 | manicore
# Processing Record 3 of Set 14 | rockland
# Processing Record 4 of Set 14 | itoman
# Processing Record 5 of Set 14 | kainantu
# Processing Record 6 of Set 14 | galle
# Processing Record 7 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 8 of Set 14 | ormond beach
# Processing Record 9 of Set 14 | aasiaat
# Processing Record 10 of Set 14 | duluth
# Processing Record 11 of Set 14 | gurupi
# Processing Record 12 of Set 14 | portland
# Processing Record 13 of Set 14 | kalmunai
# Processing Record 14 of Set 14 | san borja
# Processing Record 15 of Set 14 | novobiryusinskiy
# Processing Record 16 of Set 14 | san policarpo
# Processing Record 17 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 18 of Set 14 | pore
# Processing Record 19 of Set 14 | bontang
# Processing Record 20 of Set 14 | okhotsk
# Processing Record 21 of Set 14 | waslala
# Processing Record 22 of Set 14 | mwinilunga
# Processing Record 23 of Set 14 | grafton
# Processing Record 24 of Set 14 | nizwa
# Processing Record 25 of Set 14 | husavik
# Processing Record 26 of Set 14 | bayeux
# Processing Record 27 of Set 14 | lazaro cardenas
# Processing Record 28 of Set 14 | rincon
# Processing Record 29 of Set 14 | wadi maliz
# Processing Record 30 of Set 14 | dzhebariki-khaya
# Processing Record 31 of Set 14 | nioro
# Processing Record 32 of Set 14 | shelburne
# Processing Record 33 of Set 14 | sosnovo-ozerskoye
# Processing Record 34 of Set 14 | makhinjauri
# Processing Record 35 of Set 14 | caravelas
# Processing Record 36 of Set 14 | pittsburg
# Processing Record 37 of Set 14 | copiapo
# Processing Record 38 of Set 14 | qaqortoq
# Processing Record 39 of Set 14 | marsh harbour
# Processing Record 40 of Set 14 | yvetot
# Processing Record 41 of Set 14 | sjovegan
# Processing Record 42 of Set 14 | saint-francois
# Processing Record 43 of Set 14 | rudsar
# Processing Record 44 of Set 14 | sistranda
# Processing Record 45 of Set 14 | balikpapan
# Processing Record 46 of Set 14 | dakar
# Processing Record 47 of Set 14 | manokwari
# Processing Record 48 of Set 14 | chemnitz
# Processing Record 49 of Set 14 | sirtich
# Processing Record 50 of Set 14 | amarante do maranhao
# Processing Record 1 of Set 15 | lagoa
# Processing Record 2 of Set 15 | barcelona
# Processing Record 3 of Set 15 | mikhaylovka
# Processing Record 4 of Set 15 | tabou
# Processing Record 5 of Set 15 | tahe
# Processing Record 6 of Set 15 | qurayyat
# Processing Record 7 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 8 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 15 | verkhnyaya inta
# Processing Record 10 of Set 15 | micheweni
# Processing Record 11 of Set 15 | sedona
# Processing Record 12 of Set 15 | rawson
# Processing Record 13 of Set 15 | ituni
# City not found. Skipping...
# Processing Record 14 of Set 15 | karasjok
# Processing Record 15 of Set 15 | encruzilhada do sul
# Processing Record 16 of Set 15 | sarangani
# Processing Record 17 of Set 15 | springbok
# Processing Record 18 of Set 15 | ascension
# Processing Record 19 of Set 15 | varkkallai
# Processing Record 20 of Set 15 | borova
# Processing Record 21 of Set 15 | pitiquito
# Processing Record 22 of Set 15 | dospat
# Processing Record 23 of Set 15 | kalaleh
# Processing Record 24 of Set 15 | vila velha
# Processing Record 25 of Set 15 | ye
# City not found. Skipping...
# Processing Record 26 of Set 15 | svetlaya
# Processing Record 27 of Set 15 | poso
# Processing Record 28 of Set 15 | beysehir
# Processing Record 29 of Set 15 | mosnita noua
# Processing Record 30 of Set 15 | rio grande
# Processing Record 31 of Set 15 | nichinan
# Processing Record 32 of Set 15 | kodinsk
# Processing Record 33 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 34 of Set 15 | semey
# Processing Record 35 of Set 15 | garden city
# Processing Record 36 of Set 15 | isiolo
# Processing Record 37 of Set 15 | tinaquillo
# Processing Record 38 of Set 15 | esna
# Processing Record 39 of Set 15 | berezovyy
# Processing Record 40 of Set 15 | yuza
# Processing Record 41 of Set 15 | bayangol
# Processing Record 42 of Set 15 | uvat
# Processing Record 43 of Set 15 | dwarka
# Processing Record 44 of Set 15 | yershov
# Processing Record 45 of Set 15 | baruun-urt
# Processing Record 46 of Set 15 | sioux lookout
# Processing Record 47 of Set 15 | kaeo
# Processing Record 48 of Set 15 | darnah
# Processing Record 49 of Set 15 | bahir dar
# Processing Record 50 of Set 15 | belyy yar
# Processing Record 1 of Set 16 | dzilam gonzalez
# Processing Record 2 of Set 16 | flinders
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df=pd.DataFrame(city_data)
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Tilichiki      RU  60.4667  166.1000    284.54        74
# 1            Ushuaia      AR -54.8000  -68.3000    276.94        60
# 2           Hermanus      ZA -34.4187   19.2345    283.60        88
# 3       Punta Arenas      CL -53.1500  -70.9167    277.16        70
# 4          Grindavik      IS  63.8424  -22.4338    285.41       100
# ..               ...     ...      ...       ...       ...       ...
# 685           Darnah      LY  32.7670   22.6367    299.67        75
# 686        Bahir Dar      ET  11.5936   37.3908    289.54        95
# 687        Belyy Yar      RU  53.6039   91.3903    284.74        93
# 688  Dzilam Gonzalez      MX  21.2833  -88.9333    300.88        77
# 689         Flinders      AU -34.5833  150.8552    283.25        69
#
#      Cloudiness  Wind Speed Current Description
# 0           100        2.16     overcast clouds
# 1            20        4.12          few clouds
# 2            99        3.27     overcast clouds
# 3            75        6.17       broken clouds
# 4           100        9.26       moderate rain
# ..          ...         ...                 ...
# 685           0        7.06           clear sky
# 686         100        1.81       moderate rain
# 687           0        1.00           clear sky
# 688          91        3.63     overcast clouds
# 689           3        4.02           clear sky
#
# [690 rows x 9 columns]

# %%
# Convert Kelvin to Fahrenheit
def f(x):
    x=1.8*(x-273)+32
    return float(x)

city_data_df['Max Temp']=city_data_df['Max Temp'].apply(f)
city_data_df
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Tilichiki      RU  60.4667  166.1000    52.772        74
# 1            Ushuaia      AR -54.8000  -68.3000    39.092        60
# 2           Hermanus      ZA -34.4187   19.2345    51.080        88
# 3       Punta Arenas      CL -53.1500  -70.9167    39.488        70
# 4          Grindavik      IS  63.8424  -22.4338    54.338       100
# ..               ...     ...      ...       ...       ...       ...
# 685           Darnah      LY  32.7670   22.6367    80.006        75
# 686        Bahir Dar      ET  11.5936   37.3908    61.772        95
# 687        Belyy Yar      RU  53.6039   91.3903    53.132        93
# 688  Dzilam Gonzalez      MX  21.2833  -88.9333    82.184        77
# 689         Flinders      AU -34.5833  150.8552    50.450        69
#
#      Cloudiness  Wind Speed Current Description
# 0           100        2.16     overcast clouds
# 1            20        4.12          few clouds
# 2            99        3.27     overcast clouds
# 3            75        6.17       broken clouds
# 4           100        9.26       moderate rain
# ..          ...         ...                 ...
# 685           0        7.06           clear sky
# 686         100        1.81       moderate rain
# 687           0        1.00           clear sky
# 688          91        3.63     overcast clouds
# 689           3        4.02           clear sky
#
# [690 rows x 9 columns]
