# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Files to load
city_data_to_load="weather_data/cities.csv"

# %%
#Read the csv and  convert to DataFrame
city_data_df=pd.read_csv(city_data_to_load)
city_data_df
# Out:
#      City_ID             City Country                 Date      Lat       Lng  \
# 0          0        Bathsheba      BB  2022-07-18 21:25:24  13.2167  -59.5167
# 1          1          Huarmey      PE  2022-07-18 21:25:25 -10.0681  -78.1522
# 2          2     Manzil Salim      TN  2022-07-18 21:25:26  35.8567    8.4765
# 3          3     Punta Arenas      CL  2022-07-18 21:25:27 -53.1500  -70.9167
# 4          4             Nome      US  2022-07-18 21:20:31  64.5011 -165.4064
# ..       ...              ...     ...                  ...      ...       ...
# 552      552           Bonthe      SL  2022-07-18 21:47:23   7.5264  -12.5050
# 553      553     Christchurch      NZ  2022-07-18 21:45:08 -43.5333  172.6333
# 554      554  Fort-Shevchenko      KZ  2022-07-18 21:47:26  44.5086   50.2630
# 555      555          Taurage      LT  2022-07-18 21:47:28  55.2522   22.2897
# 556      556         Pucallpa      PE  2022-07-18 21:47:28  -8.3791  -74.5539
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0      302.49        82          40        9.26
# 1      292.53        74          64        5.39
# 2      301.44        24           0        3.57
# 3      278.21        75          75       13.38
# 4      278.19        87         100       10.80
# ..        ...       ...         ...         ...
# 552    298.11        84          99        6.99
# 553    288.26        51          75        2.06
# 554    300.26        68           0        2.80
# 555    287.69        98          97        1.97
# 556    301.17        74          40        0.00
#
# [557 rows x 10 columns]

# %%
city_data_df
# Out:
#      City_ID             City Country                 Date      Lat       Lng  \
# 0          0        Bathsheba      BB  2022-07-18 21:25:24  13.2167  -59.5167
# 1          1          Huarmey      PE  2022-07-18 21:25:25 -10.0681  -78.1522
# 2          2     Manzil Salim      TN  2022-07-18 21:25:26  35.8567    8.4765
# 3          3     Punta Arenas      CL  2022-07-18 21:25:27 -53.1500  -70.9167
# 4          4             Nome      US  2022-07-18 21:20:31  64.5011 -165.4064
# ..       ...              ...     ...                  ...      ...       ...
# 552      552           Bonthe      SL  2022-07-18 21:47:23   7.5264  -12.5050
# 553      553     Christchurch      NZ  2022-07-18 21:45:08 -43.5333  172.6333
# 554      554  Fort-Shevchenko      KZ  2022-07-18 21:47:26  44.5086   50.2630
# 555      555          Taurage      LT  2022-07-18 21:47:28  55.2522   22.2897
# 556      556         Pucallpa      PE  2022-07-18 21:47:28  -8.3791  -74.5539
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0      302.49        82          40        9.26
# 1      292.53        74          64        5.39
# 2      301.44        24           0        3.57
# 3      278.21        75          75       13.38
# 4      278.19        87         100       10.80
# ..        ...       ...         ...         ...
# 552    298.11        84          99        6.99
# 553    288.26        51          75        2.06
# 554    300.26        68           0        2.80
# 555    287.69        98          97        1.97
# 556    301.17        74          40        0.00
#
# [557 rows x 10 columns]

# %%
city_data_df=city_data_df.iloc[:,1:]
city_data_df
# Out:
#                 City Country                 Date      Lat       Lng  \
# 0          Bathsheba      BB  2022-07-18 21:25:24  13.2167  -59.5167
# 1            Huarmey      PE  2022-07-18 21:25:25 -10.0681  -78.1522
# 2       Manzil Salim      TN  2022-07-18 21:25:26  35.8567    8.4765
# 3       Punta Arenas      CL  2022-07-18 21:25:27 -53.1500  -70.9167
# 4               Nome      US  2022-07-18 21:20:31  64.5011 -165.4064
# ..               ...     ...                  ...      ...       ...
# 552           Bonthe      SL  2022-07-18 21:47:23   7.5264  -12.5050
# 553     Christchurch      NZ  2022-07-18 21:45:08 -43.5333  172.6333
# 554  Fort-Shevchenko      KZ  2022-07-18 21:47:26  44.5086   50.2630
# 555          Taurage      LT  2022-07-18 21:47:28  55.2522   22.2897
# 556         Pucallpa      PE  2022-07-18 21:47:28  -8.3791  -74.5539
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0      302.49        82          40        9.26
# 1      292.53        74          64        5.39
# 2      301.44        24           0        3.57
# 3      278.21        75          75       13.38
# 4      278.19        87         100       10.80
# ..        ...       ...         ...         ...
# 552    298.11        84          99        6.99
# 553    288.26        51          75        2.06
# 554    300.26        68           0        2.80
# 555    287.69        98          97        1.97
# 556    301.17        74          40        0.00
#
# [557 rows x 9 columns]

# %%
city_data_df.dtypes
# Out:
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
city_data_df["Max Temp"]
# Out:
# 0      302.49
# 1      292.53
# 2      301.44
# 3      278.21
# 4      278.19
#         ...
# 552    298.11
# 553    288.26
# 554    300.26
# 555    287.69
# 556    301.17
# Name: Max Temp, Length: 557, dtype: float64

# %%
# Convert K to F
def f(x):
    x = 1.8*(x-273)+32
    return float(x)

city_data_df['Max Temp']=city_data_df['Max Temp'].apply(f)
city_data_df
# Out:
#                 City Country                 Date      Lat       Lng  \
# 0          Bathsheba      BB  2022-07-18 21:25:24  13.2167  -59.5167
# 1            Huarmey      PE  2022-07-18 21:25:25 -10.0681  -78.1522
# 2       Manzil Salim      TN  2022-07-18 21:25:26  35.8567    8.4765
# 3       Punta Arenas      CL  2022-07-18 21:25:27 -53.1500  -70.9167
# 4               Nome      US  2022-07-18 21:20:31  64.5011 -165.4064
# ..               ...     ...                  ...      ...       ...
# 552           Bonthe      SL  2022-07-18 21:47:23   7.5264  -12.5050
# 553     Christchurch      NZ  2022-07-18 21:45:08 -43.5333  172.6333
# 554  Fort-Shevchenko      KZ  2022-07-18 21:47:26  44.5086   50.2630
# 555          Taurage      LT  2022-07-18 21:47:28  55.2522   22.2897
# 556         Pucallpa      PE  2022-07-18 21:47:28  -8.3791  -74.5539
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 0      85.082        82          40        9.26
# 1      67.154        74          64        5.39
# 2      83.192        24           0        3.57
# 3      41.378        75          75       13.38
# 4      41.342        87         100       10.80
# ..        ...       ...         ...         ...
# 552    77.198        84          99        6.99
# 553    59.468        51          75        2.06
# 554    81.068        68           0        2.80
# 555    58.442        98          97        1.97
# 556    82.706        74          40        0.00
#
# [557 rows x 9 columns]

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %% [markdown]
# # Plot Latitude vs Temperature

# %%
# Extract relevant fields from the DataFrame for plotting
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df['Humidity']
cloudiness=city_data_df["Cloudiness"]
wind_speed=city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds
today=time.time()
today
# Out:
# 1658330019.4384122

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
